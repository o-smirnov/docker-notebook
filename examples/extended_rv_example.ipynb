# %% [markdown]
# # Example RV notebook for example-reduction-dir on Dropbox
#
# The examples below show how to use the rv machinery. The initialization block below (between "####") is mandatory.
#
# You must select "Cell|Run All" from the above menu to re-run the notebook , and wait for it to finish running.
#
# This particular notebook is built for the example results directory that can be downloaded from Dropbox, use this link to download example-reduction-dir from Dropbox:
# https://www.dropbox.com/sh/hde4azjdscsw20c/AAB2M0w3Ttm4ioPI0bccOPE-a?dl=0
#
# Then do "cd example-reduction-dir; run-rv-notebook.sh" inside your copy of the results directory to start the notebook server and point your browser to the port indicated by the script.

# %%
### MANDATORY INIT ###
# %matplotlib inline
# %run /notebooks/rvnb_init
dirs = DirList()
######################
# adjust to fit your screen if tables below are too narrow or too wide
pandas.options.display.max_colwidth = 80

# %%
# dirs is a directory list object
# By default displays all directories under your results directory 
# dirs.show() will have the same effect
dirs
# Out:
# [<rv.DataDir at 0x7ff208057910>,
#  <rv.DataDir at 0x7ff1ff3cfa90>,
#  <rv.DataDir at 0x7ff2080578d0>,
#  <rv.DataDir at 0x7ff1ff3cfd10>,
#  <rv.DataDir at 0x7ff1ff363250>,
#  <rv.DataDir at 0x7ff1ff363190>,
#  <rv.DataDir at 0x7ff1ff363210>,
#  <rv.DataDir at 0x7ff1ff3631d0>,
#  <rv.DataDir at 0x7ff1ff363150>,
#  <rv.DataDir at 0x7ff1ff3cfa50>,
#  <rv.DataDir at 0x7ff1ff3cfb10>,
#  <rv.DataDir at 0x7ff1ff363090>,
#  <rv.DataDir at 0x7ff1ff3cfd90>,
#  <rv.DataDir at 0x7ff1ff3630d0>,
#  <rv.DataDir at 0x7ff1ff363050>]

# %%
dirs[0].fits  # gives list of FITS files in directory #0 above
# Out:
# [<rv.FITSFile.FITSFile at 0x7ff1ff3cf250>,
#  <rv.FITSFile.FITSFile at 0x7ff1ff3cf510>,
#  <rv.FITSFile.FITSFile at 0x7ff2080579d0>,
#  <rv.FITSFile.FITSFile at 0x7ff1ff3cf2d0>,
#  <rv.FITSFile.FITSFile at 0x7ff1ff3cf390>,
#  <rv.FITSFile.FITSFile at 0x7ff1ff3cf410>,
#  <rv.FITSFile.FITSFile at 0x7ff1ff3cf610>,
#  <rv.FITSFile.FITSFile at 0x7ff1ff3c37d0>,
#  <rv.FITSFile.FITSFile at 0x7ff1ff3cf590>,
#  <rv.FITSFile.FITSFile at 0x7ff1ff3cf490>]

# %%
# displays thumbnails for all FITS files in directory #0
dirs[0].fits.thumbs()
# Out:
# <h4>FITS files, /home/oms/Dropbox/Public-RATT/docker-notebook-examples/example-reduction-dir/</h4>

# %%
dirs[0].fits.thumbs(zoom=2)
# Out:
# <h4>FITS files, /home/oms/Dropbox/Public-RATT/docker-notebook-examples/example-reduction-dir/</h4>

# %%
# gives list of FITS files matching the pattern
dirs[0].fits("*s7*")
# Out:
# <h4>FITS files, /home/oms/Dropbox/Public-RATT/docker-notebook-examples/example-reduction-dir/*s7*</h4><div style="max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>size</th>
#       <th>modified</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3C147-CD-LO-spw0-s7-lwimager.fullrest.fits</td>
#       <td>134818560</td>
#       <td>Tue Apr 21 12:04:46 2015</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dirs[0].fits("*s7*").show()
dirs[0].fits("*s7*").thumbs()
# Out:
# <h4>FITS files, /home/oms/Dropbox/Public-RATT/docker-notebook-examples/example-reduction-dir/*s7*</h4><div style="max-height:1000px;max-width:1500px;overflow:auto;">
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>size</th>
#       <th>modified</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3C147-CD-LO-spw0-s7-lwimager.fullrest.fits</td>
#       <td>134818560</td>
#       <td>Tue Apr 21 12:04:46 2015</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# <h4>FITS files, /home/oms/Dropbox/Public-RATT/docker-notebook-examples/example-reduction-dir/*s7*</h4>

# %%
# list of images (PNG, JPG, etc.) in directory #3
dirs[3].images
# Out:
# []

# %%
# clickable thumbnails of same
dirs[3].images.thumbs(ncol=6)

# %%
# first FITS file in directory #0. Stokes axis is unrolled by default, but this can be controlled by
# invoking dirs[0].fits[0].show() with some extra arguments
dirs[0].fits[0]
# Out:
# 3C147-CD-LO-spw0-s7-lwimager.fullrest.fits (RA,DEC), unrolling STOKES

# %%
# and this shows how to invoke show() with some explicit arguments to control the rendering
dirs[0].fits[0].show(unroll=None,vmin=-5e-5,vmax=5e-5,zoom=4)
# Out:
# '3C147-CD-LO-spw0-s7-lwimager.fullrest.fits (RA,DEC) zoom x4 STOKES I'

# %%
# just some info about the given file
dirs[0].fits[0].info()
# Out:
# 3C147-CD-LO-spw0-s7-lwimager.fullrest.fits 4096x4096x2x1 RA---SIN,DEC--SIN,STOKES,FREQ

# %%
# A more elaborate rendering of the same file using aplpy. Note that .fullpath gives you the path to the file.
# aplpy is quite slow so we don't use it by default for all files, but this example shows you how to do
# a proper rendering
fig = aplpy.FITSFigure(dirs[0].fits[0].fullpath,slices=[0,0])
fig.show_colorscale(cmap='gist_heat',vmin=-5e-5,vmax=5e-5)
fig.add_colorbar()
